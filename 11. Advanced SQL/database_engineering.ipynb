# %% [markdown]
# # Step 2 - Database Engineering

# %%
#importing the dependencies
import pandas as pd

#importing Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy import create_engine, MetaData
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float

# %%
#determine the file to import
file1 = 'Resources/hawaii_measurements_clean.csv'
file2 = 'Resources/hawaii_stations_clean.csv'

# %%
#reading the files with pandas
HI_measurement_df = pd.read_csv(file1)
HI_stations_df = pd.read_csv(file2)

print(HI_measurement_df.head())
print(HI_stations_df.head())
# Out:
#    Unnamed: 0      station        date  prcp  tobs
# 0           0  USC00519397  2010-01-01  0.08    65
# 1           1  USC00519397  2010-01-02  0.00    63
# 2           2  USC00519397  2010-01-03  0.00    74
# 3           3  USC00519397  2010-01-04  0.00    76
# 4           4  USC00519397  2010-01-06  0.00    73
#    Unnamed: 0      station                                    name  latitude  \
# 0           0  USC00519397                    WAIKIKI 717.2, HI US   21.2716
# 1           1  USC00513117                    KANEOHE 838.1, HI US   21.4234
# 2           2  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US   21.5213
# 3           3  USC00517948                       PEARL CITY, HI US   21.3934
# 4           4  USC00518838              UPPER WAHIAWA 874.3, HI US   21.4992
#
#    longitude  elevation
# 0  -157.8168        3.0
# 1  -157.8015       14.6
# 2  -157.8374        7.0
# 3  -157.9751       11.9
# 4  -158.0111      306.6

# %%
#using the declarative base to create 2 classes, one for measurement and one for stations
Base = declarative_base()

class Measurement(Base):
    __tablename__ = 'measurement'
    
    id = Column(Integer, primary_key = True)
    station = Column(String(50))
    date = Column(String(50))
    prcp = Column(Float)
    tobs = Column(Integer)

class Station(Base):
    __tablename__ = 'station'
    
    station = Column(String, primary_key = True)
    name = Column(String(100))
    latitude = Column(Float)
    longitude = Column(Float)
    elevation = Column(Float)

# %%
#create an engine
engine = create_engine("sqlite:///hawaii.sqlite")
engine
# Out:
# Engine(sqlite:///hawaii.sqlite)

# %%
#creating a connection to the engine called `conn`
conn = engine.connect()
conn

# %%
#creating the tables into the database
Base.metadata.create_all(engine)

# %%
engine.table_names()
# Out:
# ['measurement', 'station']

# %%
#creating a session
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
#adding the measurement data to the database
for i, row in HI_measurement_df.iterrows():
    data = Measurement(
                    station = row.station,
                    date = row.date,
                    prcp = row.prcp,
                    tobs = row.tobs
                    )
    session.add(data)
    session.commit()

# %%
#adding the station data to the database
for i, row in HI_stations_df.iterrows():
    data = Station(
                    station = row.station,
                    name = row.name,
                    latitude = row.latitude,
                    longitude = row.longitude,
                    elevation = row.elevation
                    )
    session.add(data)
    session.commit()

# %%
#creating a small query to check info
station_list = session.query(Station)
for station in station_list:
    print(station.__dict__)
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145736136A0>, 'latitude': 21.2716, 'station': 'USC00519397', 'longitude': -157.8168, 'name': b'\x00\x00\x00\x00\x00\x00\x00\x00', 'elevation': 3.0}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573613710>, 'latitude': 21.4234, 'station': 'USC00513117', 'longitude': -157.8015, 'name': b'\x01\x00\x00\x00\x00\x00\x00\x00', 'elevation': 14.6}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573613780>, 'latitude': 21.5213, 'station': 'USC00514830', 'longitude': -157.8374, 'name': b'\x02\x00\x00\x00\x00\x00\x00\x00', 'elevation': 7.0}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145736137F0>, 'latitude': 21.3934, 'station': 'USC00517948', 'longitude': -157.9751, 'name': b'\x03\x00\x00\x00\x00\x00\x00\x00', 'elevation': 11.9}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573613898>, 'latitude': 21.4992, 'station': 'USC00518838', 'longitude': -158.0111, 'name': b'\x04\x00\x00\x00\x00\x00\x00\x00', 'elevation': 306.6}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573613940>, 'latitude': 21.33556, 'station': 'USC00519523', 'longitude': -157.71139, 'name': b'\x05\x00\x00\x00\x00\x00\x00\x00', 'elevation': 19.5}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145736139E8>, 'latitude': 21.45167, 'station': 'USC00519281', 'longitude': -157.84888999999995, 'name': b'\x06\x00\x00\x00\x00\x00\x00\x00', 'elevation': 32.9}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573613A90>, 'latitude': 21.3152, 'station': 'USC00511918', 'longitude': -157.9992, 'name': b'\x07\x00\x00\x00\x00\x00\x00\x00', 'elevation': 0.9}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B02B0>, 'latitude': 21.3331, 'station': 'USC00516128', 'longitude': -157.8025, 'name': b'\x08\x00\x00\x00\x00\x00\x00\x00', 'elevation': 152.4}

# %%
measurement_list = session.query(Measurement)
for measure in measurement_list:
    print(measure.__dict__)
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573609860>, 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 65, 'date': '2010-01-01', 'id': 1}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573609588>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 63, 'date': '2010-01-02', 'id': 2}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145736096D8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-01-03', 'id': 3}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573609BA8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-01-04', 'id': 4}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573609CF8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-01-06', 'id': 5}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573609C18>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 70, 'date': '2010-01-07', 'id': 6}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573609D68>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 64, 'date': '2010-01-08', 'id': 7}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573609E10>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 68, 'date': '2010-01-09', 'id': 8}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573609978>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-01-10', 'id': 9}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573609E80>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 64, 'date': '2010-01-11', 'id': 10}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573609F28>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 61, 'date': '2010-01-12', 'id': 11}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573609780>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 66, 'date': '2010-01-14', 'id': 12}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572739E80>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 65, 'date': '2010-01-15', 'id': 13}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572739E10>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 68, 'date': '2010-01-16', 'id': 14}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572747240>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 64, 'date': '2010-01-17', 'id': 15}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727475F8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '2010-01-18', 'id': 16}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572747470>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 66, 'date': '2010-01-19', 'id': 17}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145728EAD68>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 66, 'date': '2010-01-20', 'id': 18}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145728EAB70>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69, 'date': '2010-01-21', 'id': 19}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145728EA0B8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '2010-01-22', 'id': 20}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0358>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '2010-01-23', 'id': 21}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B05F8>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 71, 'date': '2010-01-24', 'id': 22}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0860>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '2010-01-25', 'id': 23}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0F60>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-01-26', 'id': 24}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0EB8>, 'prcp': 0.12, 'station': 'USC00519397', 'tobs': 68, 'date': '2010-01-27', 'id': 25}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0B38>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '2010-01-28', 'id': 26}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B09E8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 70, 'date': '2010-01-30', 'id': 27}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0A20>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 67, 'date': '2010-01-31', 'id': 28}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0C18>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 66, 'date': '2010-02-01', 'id': 29}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0D30>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '2010-02-03', 'id': 30}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0BE0>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 69, 'date': '2010-02-04', 'id': 31}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0B00>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '2010-02-05', 'id': 32}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0128>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '2010-02-06', 'id': 33}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0780>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 64, 'date': '2010-02-07', 'id': 34}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0978>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69, 'date': '2010-02-08', 'id': 35}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727B0080>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-02-09', 'id': 36}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145727927F0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-02-11', 'id': 37}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572792FD0>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 69, 'date': '2010-02-12', 'id': 38}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001457360C2E8>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 69, 'date': '2010-02-13', 'id': 39}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001457360C080>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69, 'date': '2010-02-14', 'id': 40}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001457360C160>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 71, 'date': '2010-02-15', 'id': 41}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001457360C208>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 61, 'date': '2010-02-16', 'id': 42}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001457360C358>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69, 'date': '2010-02-17', 'id': 43}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573621F60>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 63, 'date': '2010-02-19', 'id': 44}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573621518>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 64, 'date': '2010-02-20', 'id': 45}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145736216A0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 65, 'date': '2010-02-21', 'id': 46}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573621400>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 67, 'date': '2010-02-22', 'id': 47}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573621A20>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 68, 'date': '2010-02-23', 'id': 48}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573621438>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 65, 'date': '2010-02-24', 'id': 49}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573621860>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-02-25', 'id': 50}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573613A90>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-02-26', 'id': 51}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014573613588>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 66, 'date': '2010-02-28', 'id': 52}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7240>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 70, 'date': '2010-03-01', 'id': 53}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7390>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '2010-03-02', 'id': 54}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7438>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-03-03', 'id': 55}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E74E0>, 'prcp': 0.12, 'station': 'USC00519397', 'tobs': 70, 'date': '2010-03-04', 'id': 56}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7588>, 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 71, 'date': '2010-03-05', 'id': 57}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7630>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 72, 'date': '2010-03-06', 'id': 58}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E76D8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '2010-03-07', 'id': 59}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7780>, 'prcp': 0.43, 'station': 'USC00519397', 'tobs': 69, 'date': '2010-03-08', 'id': 60}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7828>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 70, 'date': '2010-03-09', 'id': 61}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E78D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-03-11', 'id': 62}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7978>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '2010-03-12', 'id': 63}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7A20>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-03-13', 'id': 64}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7AC8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 70, 'date': '2010-03-14', 'id': 65}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7B70>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 71, 'date': '2010-03-15', 'id': 66}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7C18>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 68, 'date': '2010-03-17', 'id': 67}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7CC0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 70, 'date': '2010-03-18', 'id': 68}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7D68>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '2010-03-21', 'id': 69}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7E10>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 69, 'date': '2010-03-22', 'id': 70}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7EB8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 68, 'date': '2010-03-23', 'id': 71}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145746E7F60>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-03-24', 'id': 72}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17048>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '2010-03-26', 'id': 73}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B170F0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 72, 'date': '2010-03-27', 'id': 74}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17198>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-03-28', 'id': 75}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17240>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-03-29', 'id': 76}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B172E8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-03-30', 'id': 77}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17390>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-03-31', 'id': 78}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17438>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-04-01', 'id': 79}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B174E0>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-04-02', 'id': 80}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17588>, 'prcp': 0.17, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-04-03', 'id': 81}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17630>, 'prcp': 0.15, 'station': 'USC00519397', 'tobs': 71, 'date': '2010-04-04', 'id': 82}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B176D8>, 'prcp': 0.27, 'station': 'USC00519397', 'tobs': 72, 'date': '2010-04-05', 'id': 83}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17780>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-04-06', 'id': 84}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17828>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-04-08', 'id': 85}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B178D0>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-04-09', 'id': 86}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17978>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-04-10', 'id': 87}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17A20>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-04-11', 'id': 88}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17AC8>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-04-12', 'id': 89}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17B70>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 71, 'date': '2010-04-13', 'id': 90}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17C18>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 71, 'date': '2010-04-15', 'id': 91}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17CC0>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 68, 'date': '2010-04-16', 'id': 92}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17D68>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 70, 'date': '2010-04-17', 'id': 93}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17E10>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 71, 'date': '2010-04-18', 'id': 94}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17EB8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-04-19', 'id': 95}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B17F60>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 71, 'date': '2010-04-20', 'id': 96}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E048>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-04-21', 'id': 97}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E0F0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-04-22', 'id': 98}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E198>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-04-23', 'id': 99}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E240>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-04-24', 'id': 100}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E2E8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-04-25', 'id': 101}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E390>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-04-26', 'id': 102}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E438>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-04-28', 'id': 103}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E4E0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-04-30', 'id': 104}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E588>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-05-01', 'id': 105}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E630>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-05-02', 'id': 106}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E6D8>, 'prcp': 0.2, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-05-03', 'id': 107}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E780>, 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-05-04', 'id': 108}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E828>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-05-05', 'id': 109}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E8D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '2010-05-06', 'id': 110}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1E978>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-05-07', 'id': 111}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1EA20>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-05-08', 'id': 112}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1EAC8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-05-09', 'id': 113}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1EB70>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-05-10', 'id': 114}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1EC18>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-05-11', 'id': 115}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1ECC0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-05-13', 'id': 116}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1ED68>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-05-14', 'id': 117}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1EE10>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-05-15', 'id': 118}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1EEB8>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-05-16', 'id': 119}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B1EF60>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-05-17', 'id': 120}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26048>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-05-18', 'id': 121}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B260F0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-05-19', 'id': 122}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26198>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-05-21', 'id': 123}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26240>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-05-22', 'id': 124}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B262E8>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-05-23', 'id': 125}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26390>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-05-24', 'id': 126}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26438>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-05-25', 'id': 127}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B264E0>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-05-26', 'id': 128}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26588>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-05-27', 'id': 129}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26630>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-05-28', 'id': 130}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B266D8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-05-29', 'id': 131}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26780>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-05-30', 'id': 132}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26828>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-05-31', 'id': 133}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B268D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-01', 'id': 134}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26978>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-06-02', 'id': 135}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26A20>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-03', 'id': 136}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26AC8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-06-04', 'id': 137}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26B70>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-06-05', 'id': 138}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26C18>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-06', 'id': 139}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26CC0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-06-07', 'id': 140}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26D68>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-08', 'id': 141}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26E10>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-09', 'id': 142}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26EB8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-06-10', 'id': 143}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B26F60>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-11', 'id': 144}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E048>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-12', 'id': 145}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E0F0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-13', 'id': 146}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E198>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-06-14', 'id': 147}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E240>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-15', 'id': 148}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E2E8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-16', 'id': 149}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E390>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-06-17', 'id': 150}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E438>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-06-18', 'id': 151}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E4E0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 82, 'date': '2010-06-19', 'id': 152}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E588>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-20', 'id': 153}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E630>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-21', 'id': 154}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E6D8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-22', 'id': 155}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E780>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-23', 'id': 156}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E828>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-24', 'id': 157}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E8D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-06-25', 'id': 158}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2E978>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-06-26', 'id': 159}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2EA20>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-27', 'id': 160}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2EAC8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-28', 'id': 161}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2EB70>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-29', 'id': 162}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2EC18>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-06-30', 'id': 163}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2ECC0>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-07-01', 'id': 164}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2ED68>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-07-02', 'id': 165}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2EE10>, 'prcp': 0.09, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-07-03', 'id': 166}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2EEB8>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-07-04', 'id': 167}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B2EF60>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-07-05', 'id': 168}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35048>, 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-07-06', 'id': 169}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B350F0>, 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-07-07', 'id': 170}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35198>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-07-08', 'id': 171}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35240>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-07-09', 'id': 172}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B352E8>, 'prcp': 0.09, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-07-10', 'id': 173}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35390>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-07-11', 'id': 174}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35438>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-07-12', 'id': 175}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B354E0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '2010-07-13', 'id': 176}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35588>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-07-16', 'id': 177}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35630>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-07-17', 'id': 178}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B356D8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-07-18', 'id': 179}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35780>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-07-19', 'id': 180}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35828>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '2010-07-21', 'id': 181}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B358D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-07-22', 'id': 182}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35978>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '2010-07-24', 'id': 183}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35A20>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-07-25', 'id': 184}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35AC8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-07-26', 'id': 185}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35B70>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-07-27', 'id': 186}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35C18>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-07-28', 'id': 187}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35CC0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-07-29', 'id': 188}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35D68>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-07-30', 'id': 189}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35E10>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-07-31', 'id': 190}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35EB8>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-08-01', 'id': 191}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B35F60>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-08-02', 'id': 192}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C048>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-08-03', 'id': 193}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C0F0>, 'prcp': 0.07, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-08-04', 'id': 194}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C198>, 'prcp': 0.08, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-08-05', 'id': 195}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C240>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-08-06', 'id': 196}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C2E8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '2010-08-07', 'id': 197}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C390>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-08-08', 'id': 198}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C438>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-08-09', 'id': 199}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C4E0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-08-10', 'id': 200}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C588>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-08-11', 'id': 201}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C630>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-08-12', 'id': 202}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C6D8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-08-13', 'id': 203}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C780>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-08-14', 'id': 204}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C828>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-08-15', 'id': 205}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C8D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-08-16', 'id': 206}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3C978>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-08-17', 'id': 207}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3CA20>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-08-18', 'id': 208}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3CAC8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-08-19', 'id': 209}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3CB70>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-08-20', 'id': 210}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3CC18>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-08-21', 'id': 211}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3CCC0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-08-22', 'id': 212}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3CD68>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 87, 'date': '2010-08-23', 'id': 213}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3CE10>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-08-24', 'id': 214}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3CEB8>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-08-25', 'id': 215}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B3CF60>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-08-26', 'id': 216}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45048>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-08-27', 'id': 217}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B450F0>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-08-28', 'id': 218}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45198>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-08-29', 'id': 219}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45240>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-08-30', 'id': 220}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B452E8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '2010-08-31', 'id': 221}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45390>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-09-01', 'id': 222}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45438>, 'prcp': 0.02, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-09-02', 'id': 223}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B454E0>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-09-03', 'id': 224}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45588>, 'prcp': 0.01, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-09-04', 'id': 225}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45630>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-09-05', 'id': 226}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B456D8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-09-06', 'id': 227}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45780>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-09-07', 'id': 228}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45828>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-09-08', 'id': 229}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B458D0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-09-09', 'id': 230}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45978>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-09-10', 'id': 231}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45A20>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-09-11', 'id': 232}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45AC8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-09-12', 'id': 233}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45B70>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-09-13', 'id': 234}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45C18>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-09-14', 'id': 235}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45CC0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-09-15', 'id': 236}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45D68>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-09-16', 'id': 237}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45E10>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-09-17', 'id': 238}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45EB8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-09-19', 'id': 239}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B45F60>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-09-20', 'id': 240}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C048>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-09-21', 'id': 241}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C0F0>, 'prcp': 0.04, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-09-22', 'id': 242}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C198>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-09-23', 'id': 243}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C240>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-09-24', 'id': 244}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C2E8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-09-25', 'id': 245}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C390>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-09-26', 'id': 246}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C438>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-09-27', 'id': 247}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C4E0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-09-28', 'id': 248}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C588>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-09-29', 'id': 249}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C630>, 'prcp': 0.57, 'station': 'USC00519397', 'tobs': 73, 'date': '2010-09-30', 'id': 250}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C6D8>, 'prcp': 0.31, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-10-01', 'id': 251}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C780>, 'prcp': 0.03, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-10-02', 'id': 252}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C828>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-10-03', 'id': 253}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C8D0>, 'prcp': 0.06, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-10-04', 'id': 254}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4C978>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '2010-10-05', 'id': 255}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4CA20>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-10-06', 'id': 256}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4CAC8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-10-07', 'id': 257}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4CB70>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-10-08', 'id': 258}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4CC18>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-10-09', 'id': 259}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4CCC0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-10-10', 'id': 260}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4CD68>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-10-11', 'id': 261}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4CE10>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-10-12', 'id': 262}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4CEB8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-10-13', 'id': 263}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B4CF60>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-10-15', 'id': 264}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B55048>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-10-16', 'id': 265}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B550F0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-10-17', 'id': 266}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B55198>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-10-18', 'id': 267}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B55240>, 'prcp': 0.07, 'station': 'USC00519397', 'tobs': 72, 'date': '2010-10-19', 'id': 268}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B552E8>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 74, 'date': '2010-10-20', 'id': 269}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B55390>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 80, 'date': '2010-10-21', 'id': 270}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B55438>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 77, 'date': '2010-10-22', 'id': 271}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B554E0>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 75, 'date': '2010-10-23', 'id': 272}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B55588>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-10-24', 'id': 273}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B55630>, 'prcp': 0.0, 'station': 'USC00519397', 'tobs': 78, 'date': '2010-10-25', 'id': 274}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B556D8>, 'prcp': 0.07, 'station': 'USC00519397', 'tobs': 76, 'date': '2010-10-26', 'id': 275}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014572B55780>, 'prcp': 0.05, 'station': 'USC00519397', 'tobs': 79, 'date': '2010-10-27', 'id': 276}
# ...
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E96D8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 78, 'date': '2011-05-15', 'id': 15443}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E9780>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 71, 'date': '2011-05-16', 'id': 15444}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E9828>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 68, 'date': '2011-05-17', 'id': 15445}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E98D0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 68, 'date': '2011-05-18', 'id': 15446}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E9978>, 'prcp': 0.03, 'station': 'USC00511918', 'tobs': 66, 'date': '2011-05-19', 'id': 15447}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E9A20>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 70, 'date': '2011-05-20', 'id': 15448}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E9AC8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 77, 'date': '2011-05-21', 'id': 15449}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E9B70>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 76, 'date': '2011-05-22', 'id': 15450}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E9C18>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 75, 'date': '2011-05-23', 'id': 15451}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E9CC0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 73, 'date': '2011-05-24', 'id': 15452}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E9D68>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 75, 'date': '2011-05-25', 'id': 15453}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E9E10>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 76, 'date': '2011-05-26', 'id': 15454}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E9EB8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 77, 'date': '2011-05-27', 'id': 15455}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753E9F60>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 77, 'date': '2011-05-28', 'id': 15456}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1048>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 77, 'date': '2011-05-29', 'id': 15457}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F10F0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '2011-05-30', 'id': 15458}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1198>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 73, 'date': '2011-05-31', 'id': 15459}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1240>, 'prcp': 0.02, 'station': 'USC00511918', 'tobs': 73, 'date': '2011-06-01', 'id': 15460}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F12E8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 76, 'date': '2011-06-02', 'id': 15461}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1390>, 'prcp': 0.03, 'station': 'USC00511918', 'tobs': 70, 'date': '2011-06-03', 'id': 15462}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1438>, 'prcp': 0.58, 'station': 'USC00511918', 'tobs': 71, 'date': '2011-06-04', 'id': 15463}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F14E0>, 'prcp': 0.02, 'station': 'USC00511918', 'tobs': 80, 'date': '2011-06-05', 'id': 15464}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1588>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 70, 'date': '2011-06-06', 'id': 15465}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1630>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 68, 'date': '2011-06-07', 'id': 15466}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F16D8>, 'prcp': 0.1, 'station': 'USC00511918', 'tobs': 74, 'date': '2011-06-08', 'id': 15467}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1780>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 75, 'date': '2011-06-09', 'id': 15468}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1828>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 75, 'date': '2011-06-10', 'id': 15469}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F18D0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 78, 'date': '2011-06-11', 'id': 15470}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1978>, 'prcp': 0.02, 'station': 'USC00511918', 'tobs': 76, 'date': '2011-06-12', 'id': 15471}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1A20>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 69, 'date': '2011-06-13', 'id': 15472}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1AC8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 73, 'date': '2011-06-14', 'id': 15473}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1B70>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 76, 'date': '2011-06-15', 'id': 15474}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1C18>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 72, 'date': '2011-06-16', 'id': 15475}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1CC0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 72, 'date': '2011-06-17', 'id': 15476}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1D68>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 80, 'date': '2011-06-18', 'id': 15477}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1E10>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 76, 'date': '2011-06-19', 'id': 15478}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1EB8>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 71, 'date': '2011-06-20', 'id': 15479}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F1F60>, 'prcp': 0.03, 'station': 'USC00511918', 'tobs': 68, 'date': '2011-06-21', 'id': 15480}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8048>, 'prcp': 0.1, 'station': 'USC00511918', 'tobs': 71, 'date': '2011-06-22', 'id': 15481}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F80F0>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 72, 'date': '2011-06-23', 'id': 15482}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8198>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 75, 'date': '2011-06-24', 'id': 15483}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8240>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 80, 'date': '2011-06-25', 'id': 15484}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F82E8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 75, 'date': '2011-06-26', 'id': 15485}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8390>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 74, 'date': '2011-06-27', 'id': 15486}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8438>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 74, 'date': '2011-06-28', 'id': 15487}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F84E0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 69, 'date': '2011-06-29', 'id': 15488}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8588>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 70, 'date': '2011-06-30', 'id': 15489}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8630>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 68, 'date': '2011-07-01', 'id': 15490}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F86D8>, 'prcp': 0.02, 'station': 'USC00511918', 'tobs': 79, 'date': '2011-07-02', 'id': 15491}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8780>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 77, 'date': '2011-07-03', 'id': 15492}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8828>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 77, 'date': '2011-07-04', 'id': 15493}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F88D0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 70, 'date': '2011-07-05', 'id': 15494}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8978>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 74, 'date': '2011-07-06', 'id': 15495}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8A20>, 'prcp': 0.03, 'station': 'USC00511918', 'tobs': 71, 'date': '2011-07-07', 'id': 15496}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8AC8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 75, 'date': '2011-07-08', 'id': 15497}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8B70>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 76, 'date': '2011-07-09', 'id': 15498}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8C18>, 'prcp': 0.02, 'station': 'USC00511918', 'tobs': 79, 'date': '2011-07-10', 'id': 15499}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8CC0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 71, 'date': '2011-07-11', 'id': 15500}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8D68>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 67, 'date': '2011-07-12', 'id': 15501}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8E10>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 72, 'date': '2011-07-13', 'id': 15502}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8EB8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 67, 'date': '2011-07-14', 'id': 15503}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753F8F60>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 76, 'date': '2011-07-15', 'id': 15504}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF048>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 78, 'date': '2011-07-16', 'id': 15505}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF0F0>, 'prcp': 0.02, 'station': 'USC00511918', 'tobs': 79, 'date': '2011-07-17', 'id': 15506}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF198>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 75, 'date': '2011-07-18', 'id': 15507}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF240>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 73, 'date': '2011-07-19', 'id': 15508}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF2E8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 72, 'date': '2011-07-20', 'id': 15509}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF390>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 75, 'date': '2011-07-21', 'id': 15510}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF438>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 74, 'date': '2011-07-22', 'id': 15511}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF4E0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 77, 'date': '2011-07-23', 'id': 15512}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF588>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 78, 'date': '2011-07-24', 'id': 15513}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF630>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '2011-07-25', 'id': 15514}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF6D8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 80, 'date': '2011-07-26', 'id': 15515}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF780>, 'prcp': 0.31, 'station': 'USC00511918', 'tobs': 75, 'date': '2011-07-27', 'id': 15516}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF828>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 76, 'date': '2011-07-28', 'id': 15517}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF8D0>, 'prcp': 0.07, 'station': 'USC00511918', 'tobs': 70, 'date': '2011-07-29', 'id': 15518}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FF978>, 'prcp': 0.14, 'station': 'USC00511918', 'tobs': 77, 'date': '2011-07-30', 'id': 15519}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FFA20>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '2011-07-31', 'id': 15520}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FFAC8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 67, 'date': '2011-08-01', 'id': 15521}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FFB70>, 'prcp': 0.01, 'station': 'USC00511918', 'tobs': 70, 'date': '2011-08-02', 'id': 15522}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FFC18>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 75, 'date': '2011-08-03', 'id': 15523}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FFCC0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 75, 'date': '2011-08-04', 'id': 15524}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FFD68>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '2011-08-05', 'id': 15525}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FFE10>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 72, 'date': '2011-08-06', 'id': 15526}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FFEB8>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 79, 'date': '2011-08-07', 'id': 15527}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145753FFF60>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 70, 'date': '2011-08-08', 'id': 15528}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014575409048>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 71, 'date': '2011-08-09', 'id': 15529}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x00000145754090F0>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 71, 'date': '2011-08-10', 'id': 15530}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x0000014575409198>, 'prcp': 0.0, 'station': 'USC00511918', 'tobs': 74, 'date': '2011-08-11', 'id': 15531}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
